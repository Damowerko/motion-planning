# %%
import pandas as pd
from pathlib import Path
import seaborn as sns
import wandb
from matplotlib import pyplot as plt

sns.set_theme(
    context="paper",
    style="ticks",
    font_scale=0.8,
    rc={
        "figure.figsize": (2.0, 3.5),
        "figure.dpi": 300,
        "savefig.dpi": 300,
        "text.usetex": True,
        "lines.linewidth": 0.7,
        "axes.linewidth": 0.7,
        "axes.grid": True,
        "grid.linestyle": "--",
        "grid.linewidth": 0.5,
        "pdf.fonttype": 42,
    },
)

# %%
data_dir = Path("../data/test_results")
fig_dir = Path("../figures/delay")
fig_dir.mkdir(parents=True, exist_ok=True)

# old models
models = {
    "GNN": "h0lcjb6p",
    "Decentralized CAPT (2-hop)": "d2_sq",
    "Decentralized CAPT (6-hop)": "d6_sq",
}

# %%
dfs = []
for (k, v) in models.items():
    df = pd.read_parquet(data_dir / v / "delay.parquet")
    df["policy"] = k
    dfs.append(df)
df = pd.concat(dfs)
df["step"] += 1
df["time_s"] = df["step"]
df["d(pi)"] = df["avg_dist_to_cover"]
df_d2sq = df[df["policy"] == "Decentralized CAPT (2-hop)"]

# %%
# Create the line plot
plt.figure(figsize=(7, 4))
sns.lineplot(
    data=df_d2sq[df_d2sq['delay_s'] * 2 == (2 * df_d2sq['delay_s']).astype(int)],
    x="step",
    y="d(pi)",
    hue="delay_s",
    # errorbar="sd",
)
plt.xlabel("Step")
plt.xlim(0, 200)
plt.ylabel("Coverage")

plt.show()

# %%
import numpy as np

gamma = 0.99
df["discount"] = gamma ** df["step"]

data: pd.DataFrame = (
    df.groupby(["policy", "delay_s", "trial"])
    .apply(
        lambda df: np.average(df["d(pi)"], weights=df["discount"]),
        include_groups=False,
    )
    .rename("discounted_coverage")  # type: ignore
    .to_frame()
)
data.groupby(["policy", "delay_s"])[["discounted_coverage"]].mean()

# %%
plt.figure(figsize=(5,3))
g = sns.lineplot(
    data=data,
    x="delay_s",
    y="discounted_coverage",
    hue="policy",
    style="policy",
    markers=".",
    palette="mako",
)
sns.move_legend(g, "upper left", title="Policy")
plt.xlabel("Delay")
plt.ylabel("Average $D(\Pi)$")
# plt.savefig(model_data_dir / "generalize_scale_density.pdf", bbox_inches="tight")
plt.show()

# %%
data = (
    df.groupby(["policy", "delay_s", "trial"])
    .apply(
        lambda df: np.min(df["d(pi)"]),
        include_groups=False,
    )
    .rename("max_coverage")  # type: ignore
    .to_frame()
)
data.groupby(["policy", "delay_s"])[["max_coverage"]].mean()

# %%
plt.figure(figsize=(5,3))
g = sns.lineplot(
    data=data,
    x="delay_s",
    y="max_coverage",
    hue="policy",
    style="policy",
    markers=".",
    palette="mako",
)
sns.move_legend(g, "upper left", title="Policy")
plt.xlabel("Delay")
plt.ylabel("Average $D(\Pi)$")
# plt.savefig(model_data_dir / "generalize_scale_density.pdf", bbox_inches="tight")
plt.show()
